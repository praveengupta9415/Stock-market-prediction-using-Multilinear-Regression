Target variable

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
print("Training Data:")
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("\nTesting Data:")
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# Training Data:
# X_train shape: (1424, 4)
# y_train shape: (1424,)
#
# Testing Data:
# X_test shape: (611, 4)
# y_test shape: (611,)

# %%
# # Extracting dates for the training and testing sets
# train_dates = stock_data.loc[X_train.index, 'Date'].values
# test_dates = stock_data.loc[X_test.index, 'Date'].values

# # Creating DataFrames for training and testing data
# train_df = pd.DataFrame({'Date': train_dates, 'Close Price': y_train.values, 'Prediction': np.nan})
# test_df = pd.DataFrame({'Date': test_dates, 'Close Price': y_test.values, 'Prediction': y_pred})

# # Concatenating training and testing DataFrames
# combined_df = pd.concat([train_df, test_df])

# # Printing the combined DataFrame
# print(combined_df)

# %%
# Creating a Linear Regression model
model = LinearRegression()

# %%
 #Training the model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Making predictions
y_pred = model.predict(X_test)



print("Predicted Close Prices:")
print(y_pred)
# Out:
# Predicted Close Prices:
# [118.61080425 285.5431169  147.10115367 132.07970695 131.29273648
#  160.15157122 119.53571905 130.26000543 154.19303501 196.84613225
#  164.54448824 138.88468486 142.56964351 264.54017265 146.70190813
#  274.39523903  89.97892701 122.38367964  88.74468904 257.8361385
#  140.96565707 133.35795269  85.69428359 143.17654934  98.58281055
#  150.67308742 127.55547572  97.55409321 158.01794904 128.86534078
#  155.73507991 136.83812945 119.5594025  153.39654763 156.12801998
#  237.35194222 115.2011295   83.37103208 154.75091597 115.87031676
#  144.840197   163.59996131 157.66519251 152.0594592  142.05703277
#  196.69736642 146.35685388 168.97715421 154.79571798 109.38273245
#   93.18555747 147.07933043 266.51850483 102.92310761 116.07972675
#  173.85251831 143.9750557  101.53763038 168.79268205 109.12503068
#  156.0229278  140.05632373 275.87113974 156.26937109 144.00065728
#  127.24947874 152.8299696  274.65339685 121.89767047 154.1186403
#  135.86897851 100.61055998 154.80433773 162.44677182 158.1029043
#  135.87788385 159.81625323 159.42097801 137.31799251 106.09881142
#   93.92871876 164.03189579 140.65841623 111.17174473 143.03184812
#  131.5925227  155.17539047 117.16531087 159.48847774 147.36761891
#  162.7037354  267.08723317 149.59664652 124.60546077  98.22418896
#  160.79058568 117.22373735 152.90779099 153.31070528 138.47377346
#   82.46394272 289.43486468 119.34105765 140.55381815 146.56930344
#   92.25921415 124.71874035 121.42540021 154.00574209  97.01543081
#   93.6992535  276.81110867 126.9692212  206.67352021 142.84482854
#  150.86304214 167.72229147 190.8912601  148.77291722 160.08449949
#  209.29897469 146.54926693 153.86691137 273.72915848 130.70888252
#  173.9539733  120.85069088 166.79242992 102.48250475  88.15964369
#  106.65462703 141.22531898 146.37805356 143.49990283 148.88097642
#  103.20921256 142.56821411 151.21743252 156.23330732 146.57010401
#  166.81568431 144.39040934  89.63585199 158.59189313 111.3515999
#  130.63711876 136.47548212 159.17083491 120.65408749 167.02272727
#  137.6526187  128.16550534 109.96211476 120.73639318 275.49861606
#  104.76453584 144.62933599 134.13969641 263.1232925  141.93628446
#  101.85406401]

# %%
# Extracting dates for the test set
test_dates = stock_data.loc[X_test.index, 'Date'].values

# Creating a DataFrame to store date, actual close price, and predicted close price
predictions_df = pd.DataFrame({'Date': test_dates, 'Actual Close Price': y_test.values, 'Predicted Close Price': y_pred})

# Printing the DataFrame
print(predictions_df.head(20))  # Printing the first 3 rows
# Out:
#           Date  Actual Close Price  Predicted Close Price
# 0   2016-04-12              118.35             118.610804
# 1   2018-04-19              286.20             285.543117
# 2   2013-12-11              147.00             147.101154
# 3   2012-08-22              131.80             132.079707
# 4   2015-08-17              131.00             131.292736
# 5   2015-03-12              160.00             160.151571
# 6   2016-05-13              119.55             119.535719
# 7   2013-03-19              130.15             130.260005
# 8   2013-12-23              154.70             154.193035
# 9   2017-08-21              196.15             196.846132
# 10  2014-09-18              164.85             164.544488
# 11  2014-02-17              138.90             138.884685
# 12  2014-03-26              142.75             142.569644
# 13  2018-06-25              264.50             264.540173
# 14  2014-05-05              146.70             146.701908
# 15  2017-11-22              274.05             274.395239
# 16  2011-12-29               90.10              89.978927
# 17  2016-12-07              122.30             122.383680
# 18  2011-02-25               88.60              88.744689
# 19  2018-03-23              257.90             257.836138

# %%
# Evaluating the model
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 0.16152562591885483

# %%
mse = mean_squared_error(y_test, y_pred)

# Calculate root mean squared error
rmse = np.sqrt(mse)

print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Root Mean Squared Error (RMSE): 0.4019025079778115

# %%
def forecast_next_30_days(last_week_data):
    # Assuming last_week_data contains the data for the last 30 days
    X_train = last_week_data[['Open','High','Low','Last']]  # Independent variables
    y_train = last_week_data['Close']  # Dependent variable

   
    # Example data for the next 30 days (replace with your own data)
    X_forecast = np.random.rand(30, 4)  # Independent variables for the next 7 days

    # Predict the values for the next 30 days
    y_forecast = model.predict(X_forecast)

    return y_forecast

# Example usage: assuming you have the last 30 days of data in a separate dataframe called 'last_week_data'
last_week_data = pd.DataFrame({
    'Open': np.random.rand(30),
    'High': np.random.rand(30),
    'Low' : np.random.rand(30),
    'Last': np.random.rand(30),
    'Close':np.random.rand(30)
})

# Get the forecasted values for the next 30 days
forecasted_values = forecast_next_30_days(last_week_data)

# Print the forecasted values for the next 30 days
print("Forecasted values for the next 30 days:", forecasted_values)
# Out:
# Forecasted values for the next 30 days: [0.89579856 0.60441708 0.91471301 0.60218537 0.68560173 0.12978336
#  1.00831324 0.86941793 0.96492829 0.85236443 0.67812209 0.73406728
#  0.2252374  0.26704185 0.82697449 0.4574626  0.90826548 0.86467003
#  0.776897   0.84824789 0.68292772 0.53686288 0.92829205 0.2910662
#  0.26015308 0.66568441 0.63324818 0.54210835 0.1834289  0.7769549 ]
# C:\Users\DELL\anaconda3\envs\tensor\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, color='blue')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red')  # Diagonal line
plt.title('Close vs Predicted Values')
plt.xlabel('close Values')
plt.ylabel('Predicted Values')
plt.show()
